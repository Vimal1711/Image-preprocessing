# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Reading the image from the present directory
image = cv2.imread(r"C:\Users\Vimal\Downloads\smoke.jpeg")
# Resizing the image for compatibility
image = cv2.resize(image, (224,224))

# The initial processing of the image
# image = cv2.medianBlur(image, 3)
image_bw = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# The declaration of CLAHE
# clipLimit -> Threshold for contrast limiting
clahe = cv2.createCLAHE(clipLimit=5)
final_img = clahe.apply(image_bw) + 5

# Ordinary thresholding the same image
_, ordinary_img = cv2.threshold(image_bw, 155, 255, cv2.THRESH_BINARY)


output = [image, final_img]
titles = ['Original Image', ' Equilised']

for i in range(2):
    plt.subplot(1,3, i+1)
    plt.imshow(output[i])
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import cv2
import os

# Input and Output directories
input_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\Fire"
output_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\clahe_Fire"

# Ensure the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through all files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith((".jpg", ".jpeg", ".png")):  # Process only image files
        # Read the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        if image is None:
            continue  # Skip if the image cannot be read

        # Resize the image
        image = cv2.resize(image, (224, 224))

        # Convert to grayscale
        image_bw = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Apply CLAHE
        clahe = cv2.createCLAHE(clipLimit=5)
        final_img = clahe.apply(image_bw) + 5

        # Ordinary thresholding
        _, ordinary_img = cv2.threshold(image_bw, 155, 255, cv2.THRESH_BINARY)

        # Save the processed images to the output directory
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, final_img)

print("Processing complete.")
# Out:
# Processing complete.

# %%
import cv2
import os

# Input and Output directories
input_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\Fire"
output_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\HSV_clahe_Fire"

# Ensure the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through all files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith((".jpg", ".jpeg", ".png")):  # Process only image files
        # Read the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        if image is None:
            continue  # Skip if the image cannot be read

        # Resize the image
        image = cv2.resize(image, (224, 224))

        # Convert to HSV color space
        image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Process the HSV channels here as needed
        # For example, you can access the channels as follows:
        hue_channel = image_hsv[:, :, 0]
        saturation_channel = image_hsv[:, :, 1]
        value_channel = image_hsv[:, :, 2]

        # Perform further processing on the channels if required

        # Save the processed images in the output directory
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, image_hsv)

print("Processing complete.")
# Out:
# Processing complete.

# %%
import cv2
import os

# Input and Output directories
input_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\Fire"
output_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\HSVLAB_clahe_Fire"

# Ensure the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through all files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith((".jpg", ".jpeg", ".png")):  # Process only image files
        # Read the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        if image is None:
            continue  # Skip if the image cannot be read

        # Resize the image
        image = cv2.resize(image, (224, 224))

        # Convert to HSV color space
        image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Convert to LAB color space
        image_lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

        # Process the HSV and LAB channels here as needed
        # For example, you can access the channels as follows:
#         hue_channel = image_hsv[:, :, 0]
#         saturation_channel = image_hsv[:, :, 1]
#         value_channel = image_hsv[:, :, 2]

        # Similarly, access the LAB channels:
        l_channel = image_lab[:, :, 0]
        a_channel = image_lab[:, :, 1]
        b_channel = image_lab[:, :, 2]

        # Perform further processing on the channels if required

        # Save the processed images in the output directory
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, image_hsv)  # You can save the HSV or LAB image as needed

print("Processing complete.")
# Out:
# Processing complete.

# %%
def clahe_img(img):
    r, g, b = cv2.split(img)
    clahe = cv2.createCLAHE(clipLimit = 2.0, tileGridSize = (8, 8))
    op_R_2, op_G_2, op_B_2 = clahe.apply(r), clahe.apply(g),clahe.apply(b)
    img_op_clahe = cv2.merge((op_R_2, op_G_2, op_B_2))
    return img_op_clahe

# Input and Output directories
# input_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\Fire"
# output_dir = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\HSVLAB_clahe_Fire"

source_ds = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\Fire"
destination_ds = r"C:\Users\Vimal\Desktop\ML -Python\Sukriti\Dataset\Testing\HSVLAB_clahe_Fire"

for class_name in os.listdir(source_ds):
    class_dir = os.path.join(source_ds, class_name)
    dest_class_dir = os.path.join(destination_ds+'CLAHE', class_name)

    # Create the destination class directory if it doesn't exist
    os.makedirs(dest_class_dir, exist_ok=True)

    for img_name in os.listdir(class_dir):
        img_path = os.path.join(class_dir, img_name)
        img = cv2.imread(img_path)

        if img is not None:
            equ_img = clahe_img(img)
            dest_img_path = os.path.join(dest_class_dir, img_name)
            cv2.imwrite(dest_img_path, equ_img)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Input In [20], in <cell line: 15>()
#      19 # Create the destination class directory if it doesn't exist
#      20 os.makedirs(dest_class_dir, exist_ok=True)
# ---> 22 for img_name in os.listdir(class_dir):
#      23     img_path = os.path.join(class_dir, img_name)
#      24     img = cv2.imread(img_path)
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:\\Users\\Vimal\\Desktop\\ML -Python\\Sukriti\\Dataset\\Testing\\Fire\\fire_0002.jpg'
